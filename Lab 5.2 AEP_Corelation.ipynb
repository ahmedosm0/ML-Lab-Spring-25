# %%
import pandas as pd
import numpy as np
#from dataprep.datasets import load_dataset   # Used to import / load dataset
#from dataprep.eda import create_report   # Used to load Report formate

# %%
df=pd.read_csv(r'C:\Users\hp\Documents\ML Lab Spring 25\1_Orignal_AEP_hourly.csv', index_col=['Datetime'], parse_dates=['Datetime'])
df.head()
# Out:
#                          aep  year_day  holiday  weekend  winter  spring  \
# Datetime
# 2004-12-31 01:00:00  13478.0       366      NaN        0       1       0
# 2004-12-31 02:00:00  12865.0       366      NaN        0       1       0
# 2004-12-31 03:00:00  12577.0       366      NaN        0       1       0
# 2004-12-31 04:00:00  12517.0       366      NaN        0       1       0
# 2004-12-31 05:00:00  12670.0       366      NaN        0       1       0
#
#                      summer  fall  hour  month  day_of_week
# Datetime
# 2004-12-31 01:00:00       0     0     1     12            4
# 2004-12-31 02:00:00       0     0     2     12            4
# 2004-12-31 03:00:00       0     0     3     12            4
# 2004-12-31 04:00:00       0     0     4     12            4
# 2004-12-31 05:00:00       0     0     5     12            4

# %%
df=pd.read_csv(r'C:\Users\hp\Documents\ML Lab Spring 25\1_Orignal_AEP_hourly.csv', index_col=['Datetime'], parse_dates=['Datetime'])
df.head()
# Out:
#                          aep  year_day  holiday  weekend  winter  spring  \
# Datetime
# 2004-12-31 01:00:00  13478.0       366      NaN        0       1       0
# 2004-12-31 02:00:00  12865.0       366      NaN        0       1       0
# 2004-12-31 03:00:00  12577.0       366      NaN        0       1       0
# 2004-12-31 04:00:00  12517.0       366      NaN        0       1       0
# 2004-12-31 05:00:00  12670.0       366      NaN        0       1       0
#
#                      summer  fall  hour  month  day_of_week
# Datetime
# 2004-12-31 01:00:00       0     0     1     12            4
# 2004-12-31 02:00:00       0     0     2     12            4
# 2004-12-31 03:00:00       0     0     3     12            4
# 2004-12-31 04:00:00       0     0     4     12            4
# 2004-12-31 05:00:00       0     0     5     12            4

# %%
print('pearson\n\n',df.corrwith(df["aep"],method="pearson"))
# Out:
# pearson
#
#  aep            1.000000
# year_day      -0.124725
# holiday             NaN
# weekend       -0.267136
# winter         0.328284
# spring        -0.246480
# summer         0.139730
# fall          -0.220951
# hour           0.420941
# month         -0.126000
# day_of_week   -0.219867
# dtype: float64

# %%
print('kendall\n\n',df.corrwith(df["aep"],method="kendall"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print('kendall\n\n',df.corrwith(df["aep"],method="kendall"))
#
# File c:\Users\hp\Documents\ML Lab Spring 25\.venv\Lib\site-packages\pandas\core\frame.py:11295, in DataFrame.corrwith(self, other, axis, drop, method, numeric_only)
#   11292 this = self._get_numeric_data() if numeric_only else self
#   11294 if isinstance(other, Series):
# > 11295     return this.apply(lambda x: other.corr(x, method=method), axis=axis)
#   11297 if numeric_only:
#   11298     other = other._get_numeric_data()
#
# File c:\Users\hp\Documents\ML Lab Spring 25\.venv\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)  10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\hp\Documents\ML Lab Spring 25\.venv\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\hp\Documents\ML Lab Spring 25\.venv\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\Users\hp\Documents\ML Lab Spring 25\.venv\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File c:\Users\hp\Documents\ML Lab Spring 25\.venv\Lib\site-packages\pandas\core\frame.py:11295, in DataFrame.corrwith.<locals>.<lambda>(x)
#   11292 this = self._get_numeric_data() if numeric_only else self
#   11294 if isinstance(other, Series):
# > 11295     return this.apply(lambda x: other.corr(x, method=method), axis=axis)
#   11297 if numeric_only:
#   11298     other = other._get_numeric_data()
#
# File c:\Users\hp\Documents\ML Lab Spring 25\.venv\Lib\site-packages\pandas\core\series.py:2977, in Series.corr(self, other, method, min_periods)
#    2974 other_values = other.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    2976 if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2977     return nanops.nancorr(
#    2978         this_values, other_values, method=method, min_periods=min_periods
#    2979     )
#    2981 raise ValueError(
#    2982     "method must be either 'pearson', "
#    2983     "'spearman', 'kendall', or a callable, "
#    2984     f"'{method}' was supplied"
#    2985 )
#
# File c:\Users\hp\Documents\ML Lab Spring 25\.venv\Lib\site-packages\pandas\core\nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      81     raise TypeError(
#      82         f"reduction operation '{f_name}' not allowed for this dtype"
#      83     )
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
#
# File c:\Users\hp\Documents\ML Lab Spring 25\.venv\Lib\site-packages\pandas\core\nanops.py:1614, in nancorr(a, b, method, min_periods)
#    1611 a = _ensure_numeric(a)
#    1612 b = _ensure_numeric(b)
# -> 1614 f = get_corr_func(method)
#    1615 return f(a, b)
#
# File c:\Users\hp\Documents\ML Lab Spring 25\.venv\Lib\site-packages\pandas\core\nanops.py:1622, in get_corr_func(method)
#    1618 def get_corr_func(
#    1619     method: CorrelationMethod,
#    1620 ) -> Callable[[np.ndarray, np.ndarray], float]:
#    1621     if method == "kendall":
# -> 1622         from scipy.stats import kendalltau
#    1624         def func(a, b):
#    1625             return kendalltau(a, b)[0]
#
# ModuleNotFoundError: No module named 'scipy'

# %%
print('spearman\n\n',df.corrwith(df["aep"],method="spearman"))
# Out:
# spearman
#
#  aep            1.000000
# year_day      -0.123249
# holiday       -0.050335
# weekend       -0.267060
# winter         0.341147
# spring        -0.242178
# summer         0.120189
# fall          -0.218564
# hour           0.431821
# month         -0.123443
# day_of_week   -0.219619
# dtype: float64

# %%
df.isnull().sum()
# Out:
# aep            0
# year_day       0
# holiday        0
# weekend        0
# winter         0
# spring         0
# summer         0
# fall           0
# hour           0
# month          0
# day_of_week    0
# dtype: int64
